# %%
'''
IsotonicRegression and LinearRegression
using Toyota.csv
'''
import pandas as pd
import numpy as np

data = pd.read_csv('C:/Users/a/Documents/Toyota__.csv')

# %%
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from sklearn.isotonic import IsotonicRegression
from sklearn.linear_model import LinearRegression
from pylab import *

# %matplotlib inline

# %%
# oil price and Toyota column LinearRegression 
oil_price = data['oil price']
Toyota = data['Toyota']
ir = IsotonicRegression()

#IsotonicRegression #수축회귀?
#Toyota_fit_ir = ir.fit_transform(oil_price,Toyota)
#print Toyota_fit_ir

plt.figure()
#plt.plot(oil_price,Toyota_fit_ir,'ro')

plt.plot(oil_price,Toyota,'ro')
plt.xlabel('OilPrice')
plt.ylabel('Toyota')

lr = LinearRegression()
Toyota_fit_lr=lr.fit(oil_price[:,np.newaxis],Toyota)

oilprice_plot=plt.plot(x,lr.predict(x[:,np.newaxis]),'-b')
# x = oil price , y = Toyota

print "Max OilPrice: " , np.max(oil_price) 
print "Min OilPrice: " , np.min(oil_price)
print "Median OilPrice: ", np.median(oil_price)
print "Mean OilPrice ", round(np.mean(oil_price),2)
# Out:
# Max OilPrice:  109.53
# Min OilPrice:  47.22
# Median OilPrice:  93.86
# Mean OilPrice  89.84

# %%
#IsotonicRegression #수축회귀?
un_rate = data['unemployee rate']
Toyota = data['Toyota']
ir = IsotonicRegression()

plt.figure()
plt.plot(un_rate,Toyota,'ro')
plt.xlabel('Unemployed rate')
plt.ylabel('Toyota')

lr = LinearRegression()
Toyota_fit_lr=lr.fit(un_rate[:,np.newaxis],Toyota)

un_rate_plot=plt.plot(un_rate,lr.predict(un_rate[:,np.newaxis]),'-b')
# x = unemployee rate , y = Toyota

print "Max OilPrice: " , np.max(un_rate) 
print "Min OilPrice: " , np.min(un_rate)
print "Median OilPrice: ", np.median(un_rate)
print "Mean OilPrice ", round(np.mean(un_rate),2)
# Out:
# Max OilPrice:  10.6
# Min OilPrice:  5.4
# Median OilPrice:  8.1
# Mean OilPrice  7.93

# %%
cpi = data['CPI']
Toyota = data['Toyota']

plt.figure()
plt.plot(cpi,Toyota,'ro')
plt.xlabel('Consumer Price Index for All Urban Consumers: All Items')
plt.ylabel('Toyota')

lr = LinearRegression()
Toyota_fit_lr=lr.fit(cpi[:,np.newaxis],Toyota)

CPI_plot=plt.plot(cpi,lr.predict(cpi[:,np.newaxis]),'-b')
# x = CPI , y = Toyota

print "Max OilPrice: " , np.max(cpi) 
print "Min OilPrice: " , np.min(cpi)
print "Median OilPrice: ", np.median(cpi)
print "Mean OilPrice ", round(np.mean(cpi),2)
# Out:
# Max OilPrice:  238.343
# Min OilPrice:  216.687
# Median OilPrice:  230.085
# Mean OilPrice  228.74

# %%
stock = data['toyota stock']
Toyota = data['Toyota']

plt.figure()
plt.plot(stock,Toyota,'ro')
plt.xlabel('Toyota Stock')
plt.ylabel('Toyota')

lr = LinearRegression()
Toyota_fit_lr=lr.fit(stock[:,np.newaxis],Toyota)

Stock_plot=plt.plot(stock,lr.predict(stock[:,np.newaxis]),'-b')
# x = toyota Stock , y = Toyota

print "Max OilPrice: " , np.max(stock) 
print "Min OilPrice: " , np.min(stock)
print "Median OilPrice: ", np.median(stock)
print "Mean OilPrice ", round(np.mean(stock),2)
# Out:
# Max OilPrice:  138.76
# Min OilPrice:  63.96
# Median OilPrice:  83.9
# Mean OilPrice  95.01

# %%
TenYear = data['10-Year Forward Inflation Expectation Rate']
Toyota = data['Toyota']

plt.figure()
plt.plot(TenYear,Toyota,'ro')
plt.xlabel('10-Year Forward Inflation Expectation Rate')
plt.ylabel('Toyota')

lr = LinearRegression()
Toyota_fit_lr=lr.fit(TenYear[:,np.newaxis],Toyota)

TenYear_plot=plt.plot(TenYear,lr.predict(TenYear[:,np.newaxis]),'-b')
# x = 10-Year Forward Inflation Expectation Rate , y = Toyota

print "Max OilPrice: " , np.max(TenYear) 
print "Min OilPrice: " , np.min(TenYear)
print "Median OilPrice: ", np.median(TenYear)
print "Mean OilPrice ", round(np.mean(TenYear),2)
# Out:
# Max OilPrice:  3.85
# Min OilPrice:  1.53
# Median OilPrice:  2.54
# Mean OilPrice  2.51
