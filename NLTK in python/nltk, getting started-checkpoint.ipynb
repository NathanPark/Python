# %%
# This ipynd is copied at http://www.nltk.org/book/ch01.html
# start nltk Getting start 2015.05.06 maked Nathan

import nltk
nltk.download()
# 해당 파일 3개가 있다 전부 다 다운받길 바람.

from nltk.book import *
# Out:
# showing info http://www.nltk.org/nltk_data/

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
text1.concordance("monstrous")
# monstrous 라는 단어가 들어있는 부분을 나타내준다 text1에서
# monstrous의 의미는 거대한, 큰, 괴물같은
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.similar("monstrous")
# Out:
# imperial subtly impalpable pitiable curious abundant perilous
# trustworthy untoward singular lamentable few determined maddens
# horrible tyrannical lazy mystifying christian exasperate

# %%
text2.similar("monstrous")
# Out:
# very exceedingly so heartily a great good amazingly as sweet
# remarkably extremely vast

# %%
text2.common_contexts(["monstrous","very"])
# Out:
# a_pretty is_pretty a_lucky am_glad be_glad

# %%
# %matplotlib inline

# %%
text4.dispersion_plot(["citizens","democracy","freedom","duties","America"])
# citizens, democracy, freedom, duties, America의 빈도를 보여준다.

# %%
len(text3)
# Out:
# 44764

# %%
text3.tokens
# Out:
# [u'In',
#  u'the',
#  u'beginning',
#  u'God',
#  u'created',
#  u'the',
#  u'heaven',
#  u'and',
#  u'the',
#  u'earth',
#  u'.',
#  u'And',
#  u'the',
#  u'earth',
#  u'was',
#  u'without',
#  u'form',
#  u',',
#  u'and',
#  u'void',
#  u';',
#  u'and',
#  u'darkness',
#  u'was',
#  u'upon',
#  u'the',
#  u'face',
#  u'of',
#  u'the',
#  u'deep',
#  u'.',
#  u'And',
#  u'the',
#  u'Spirit',
#  u'of',
#  u'God',
#  u'moved',
#  u'upon',
#  u'the',
#  u'face',
#  u'of',
#  u'the',
#  u'waters',
#  u'.',
#  u'And',
#  u'God',
#  u'said',
#  u',',
#  u'Let',
#  u'there',
#  u'be',
#  u'light',
#  u':',
#  u'and',
#  u'there',
#  u'was',
#  u'light',
#  u'.',
#  u'And',
#  u'God',
#  u'saw',
#  u'the',
#  u'light',
#  u',',
#  u'that',
#  u'it',
#  u'was',
#  u'good',
#  u':',
#  u'and',
#  u'God',
#  u'divided',
#  u'the',
#  u'light',
#  u'from',
#  u'the',
#  u'darkness',
#  u'.',
#  u'And',
#  u'God',
#  u'called',
#  u'the',
#  u'light',
#  u'Day',
#  u',',
#  u'and',
#  u'the',
# ...

# %%
set(text3)
# Out:
# {u'alo',
#  u'Leah',
#  u'Night',
#  u'Matred',
#  u'four',
#  u'hath',
#  u'protest',
#  u'sleep',
#  u'captain',
#  u'integrity',
#  u'yonder',
#  u'Ehi',
#  u'sevens',
#  u'whose',
#  u'feeding',
#  u'Peniel',
#  u'intreat',
#  u'sinew',
#  u'whatsoever',
#  u'under',
#  u'lord',
#  u'spee',
#  u'worth',
#  u'Mehujael',
#  u'merchant',
#  u'tarry',
#  u'void',
#  u'rise',
#  u'every',
#  u'nourished',
#  u'confederate',
#  u'wagons',
#  u'Gether',
#  u'Lest',
#  u'clothed',
#  u'conceive',
#  u'red',
#  u'guiding',
#  u'Go',
#  u'clothes',
#  u'favoured',
#  u'parted',
#  u'Rachel',
#  u'force',
#  u'nigh',
#  u'welfare',
#  u'direct',
#  u'second',
#  u'street',
#  u'creepeth',
#  u'air',
#  u'Hadoram',
#  u'even',
#  u'Canaan',
#  u'hide',
#  u'deferred',
#  u'hate',
#  u'generatio',
#  u'fatness',
#  u'lights',
#  u'above',
#  u'Put',
#  u'ever',
#  u'told',
#  u'Havilah',
#  u'herb',
#  u'men',
#  u'kindred',
#  u'Mizpah',
#  u'drew',
#  u'herd',
#  u'met',
#  u'Mahanaim',
# ...

# %%
sorted(set(text3))
# Out:
# [u'!',
#  u"'",
#  u'(',
#  u')',
#  u',',
#  u',)',
#  u'.',
#  u'.)',
#  u':',
#  u';',
#  u';)',
#  u'?',
#  u'?)',
#  u'A',
#  u'Abel',
#  u'Abelmizraim',
#  u'Abidah',
#  u'Abide',
#  u'Abimael',
#  u'Abimelech',
#  u'Abr',
#  u'Abrah',
#  u'Abraham',
#  u'Abram',
#  u'Accad',
#  u'Achbor',
#  u'Adah',
#  u'Adam',
#  u'Adbeel',
#  u'Admah',
#  u'Adullamite',
#  u'After',
#  u'Aholibamah',
#  u'Ahuzzath',
#  u'Ajah',
#  u'Akan',
#  u'All',
#  u'Allonbachuth',
#  u'Almighty',
#  u'Almodad',
#  u'Also',
#  u'Alvah',
#  u'Alvan',
#  u'Am',
#  u'Amal',
#  u'Amalek',
#  u'Amalekites',
#  u'Ammon',
#  u'Amorite',
#  u'Amorites',
#  u'Amraphel',
#  u'An',
#  u'Anah',
#  u'Anamim',
#  u'And',
#  u'Aner',
#  u'Angel',
#  u'Appoint',
#  u'Aram',
#  u'Aran',
#  u'Ararat',
#  u'Arbah',
#  u'Ard',
#  u'Are',
#  u'Areli',
#  u'Arioch',
#  u'Arise',
#  u'Arkite',
#  u'Arodi',
#  u'Arphaxad',
#  u'Art',
#  u'Arvadite',
#  u'As',
#  u'Asenath',
#  u'Ashbel',
#  u'Asher',
#  u'Ashkenaz',
# ...

# %%
len(set(text3))/len(text3)
# 라운드 함수가 지정되어있나? 값이 틀리다.
# Out:
# 0

# %%
len(set(text3))
# Out:
# 2789

# %%
len(text3)
# Out:
# 44764

# %%
text3.count("smote")
#smote라는 단어가 나오는 빈도
# Out:
# 5

# %%
100 * text4.count('a') / len(text4)
# Out:
# 1

# %%
def lexical_diversity(text):
        return len(set(text)) / len(text)

# %%
def percentage(count, total):
    return 100 * count / total

# %%
lexical_diversity(text3)
# Out:
# 0.0

# %%
round(percentage(4,5),2)
# Out:
# 80.0

# %%
round(percentage(text4.count('a'),len(text4)),2)
# Out:
# 1.0

# %%
# Text as List of Words
sent1 = ['Call','me','Ishmael','.']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
lexical_diversity(sent1)
# Out:
# 1

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
['Monty','Python']+['and','the','Holy','Grail']
# Out:
# ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']

# %%
sent1+sent2+sent3+sent4
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.',
#  'In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.',
#  'Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
sent1.append("some")

# %%
sent1
# append로 추가
# Out:
# ['Call', 'me', 'Ishmael', '.', 'some']

# %%
#Indexing Lists
text4[173]
#text4의 173번째 단어는
# Out:
# u'awaken'

# %%
text4.index('awaken')
# Out:
# 173

# %%
text5[16715:16735]
# Out:
# [u'U86',
#  u'thats',
#  u'why',
#  u'something',
#  u'like',
#  u'gamefly',
#  u'is',
#  u'so',
#  u'good',
#  u'because',
#  u'you',
#  u'can',
#  u'actually',
#  u'play',
#  u'a',
#  u'full',
#  u'game',
#  u'without',
#  u'buying',
#  u'it']

# %%
sent1= ['Call','me','Ishmael','.']

# %%
my_sent= ['Bravely', 'bold', 'Sir', 'Robin', ',', 'rode','forth', 'from', 'Camelot', '.']

# %%
noun_phrase = my_sent[1:4]
noun_phrase
# Out:
# ['bold', 'Sir', 'Robin']

# %%
wOrDs=sorted(noun_phrase)
wOrDs
# Out:
# ['Robin', 'Sir', 'bold']

# %%
vocab = set(text1)
vocab_size = len(vocab)
vocab_size
# Out:
# 19317

# %%
# String
name = 'Nathan'
name[0]
# Out:
# 'N'

# %%
name*2
# Out:
# 'NathanNathan'

# %%
#Simple Statics
# 3.1 Frequency Distributions

fdist1 = FreqDist(text1)
# 빈도수를 나타냄

print(fdist1)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
fdist1.most_common(50)
# 빈도수 상위 50개
# Out:
# [(u',', 18713),
#  (u'the', 13721),
#  (u'.', 6862),
#  (u'of', 6536),
#  (u'and', 6024),
#  (u'a', 4569),
#  (u'to', 4542),
#  (u';', 4072),
#  (u'in', 3916),
#  (u'that', 2982),
#  (u"'", 2684),
#  (u'-', 2552),
#  (u'his', 2459),
#  (u'it', 2209),
#  (u'I', 2124),
#  (u's', 1739),
#  (u'is', 1695),
#  (u'he', 1661),
#  (u'with', 1659),
#  (u'was', 1632),
#  (u'as', 1620),
#  (u'"', 1478),
#  (u'all', 1462),
#  (u'for', 1414),
#  (u'this', 1280),
#  (u'!', 1269),
#  (u'at', 1231),
#  (u'by', 1137),
#  (u'but', 1113),
#  (u'not', 1103),
#  (u'--', 1070),
#  (u'him', 1058),
#  (u'from', 1052),
#  (u'be', 1030),
#  (u'on', 1005),
#  (u'so', 918),
#  (u'whale', 906),
#  (u'one', 889),
#  (u'you', 841),
#  (u'had', 767),
#  (u'have', 760),
#  (u'there', 715),
#  (u'But', 705),
#  (u'or', 697),
#  (u'were', 680),
#  (u'now', 646),
#  (u'which', 640),
#  (u'?', 637),
#  (u'me', 627),
#  (u'like', 624)]

# %%
fdist1['whale']
# Out:
# 906

# %%
V = set(text1)
long_words = [ w for w in V if len(w) > 15]
sorted(long_words)

# 문자의 길이가 15인것들을 뽑아내라
# Out:
# [u'CIRCUMNAVIGATION',
#  u'Physiognomically',
#  u'apprehensiveness',
#  u'cannibalistically',
#  u'characteristically',
#  u'circumnavigating',
#  u'circumnavigation',
#  u'circumnavigations',
#  u'comprehensiveness',
#  u'hermaphroditical',
#  u'indiscriminately',
#  u'indispensableness',
#  u'irresistibleness',
#  u'physiognomically',
#  u'preternaturalness',
#  u'responsibilities',
#  u'simultaneousness',
#  u'subterraneousness',
#  u'supernaturalness',
#  u'superstitiousness',
#  u'uncomfortableness',
#  u'uncompromisedness',
#  u'undiscriminating',
#  u'uninterpenetratingly']

# %%
len(sorted(long_words))
# Out:
# 24

# %%
fdist5 = FreqDist(text5)
sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] >7)
# 문자열이 7개 이상이거나 빈도수가 7개 이상이면 출력
# Out:
# [u'#14-19teens',
#  u'#talkcity_adults',
#  u'((((((((((',
#  u'........',
#  u'Question',
#  u'actually',
#  u'anything',
#  u'computer',
#  u'cute.-ass',
#  u'everyone',
#  u'football',
#  u'innocent',
#  u'listening',
#  u'remember',
#  u'seriously',
#  u'something',
#  u'together',
#  u'tomorrow',
#  u'watching']

# %%
list(bigrams(['more','is','said','than','done']))
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text8.collocations()
# Out:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
[w for w in text1]
# Out:
# [u'[',
#  u'Moby',
#  u'Dick',
#  u'by',
#  u'Herman',
#  u'Melville',
#  u'1851',
#  u']',
#  u'ETYMOLOGY',
#  u'.',
#  u'(',
#  u'Supplied',
#  u'by',
#  u'a',
#  u'Late',
#  u'Consumptive',
#  u'Usher',
#  u'to',
#  u'a',
#  u'Grammar',
#  u'School',
#  u')',
#  u'The',
#  u'pale',
#  u'Usher',
#  u'--',
#  u'threadbare',
#  u'in',
#  u'coat',
#  u',',
#  u'heart',
#  u',',
#  u'body',
#  u',',
#  u'and',
#  u'brain',
#  u';',
#  u'I',
#  u'see',
#  u'him',
#  u'now',
#  u'.',
#  u'He',
#  u'was',
#  u'ever',
#  u'dusting',
#  u'his',
#  u'old',
#  u'lexicons',
#  u'and',
#  u'grammars',
#  u',',
#  u'with',
#  u'a',
#  u'queer',
#  u'handkerchief',
#  u',',
#  u'mockingly',
#  u'embellished',
#  u'with',
#  u'all',
#  u'the',
#  u'gay',
#  u'flags',
#  u'of',
#  u'all',
#  u'the',
#  u'known',
#  u'nations',
#  u'of',
#  u'the',
#  u'world',
#  u'.',
#  u'He',
#  u'loved',
#  u'to',
#  u'dust',
#  u'his',
#  u'old',
#  u'grammars',
#  u';',
#  u'it',
#  u'somehow',
#  u'mildly',
# ...

# %%
fdist = FreqDist(len(w) for w in text1)
print (fdist)
# Out:
# <FreqDist with 19 samples and 260819 outcomes>

# %%
fdist
# Out:
# FreqDist({3: 50223, 1: 47933, 4: 42345, 2: 38513, 5: 26597, 6: 17111, 7: 14399, 8: 9966, 9: 6428, 10: 3528, ...})

# %%
fdist.most_common()
# Out:
# [(3, 50223),
#  (1, 47933),
#  (4, 42345),
#  (2, 38513),
#  (5, 26597),
#  (6, 17111),
#  (7, 14399),
#  (8, 9966),
#  (9, 6428),
#  (10, 3528),
#  (11, 1873),
#  (12, 1053),
#  (13, 567),
#  (14, 177),
#  (15, 70),
#  (16, 22),
#  (17, 12),
#  (18, 1),
#  (20, 1)]

# %%
fdist[3]
# Out:
# 50223

# %%
fdist.freq(3)
# Out:
# 0.19255882431878046

# %%
sent7
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.']

# %%
[w for w in sent7 if len(w) < 4 ]
# Out:
# [',', '61', 'old', ',', 'the', 'as', 'a', '29', '.']

# %%
[w for w in sent7 if len(w) == 4 ]
# Out:
# ['will', 'join', 'Nov.']

# %%
[w for w in sent7 if len(w) != 4]
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  '29',
#  '.']

# %%
sorted(w for w in set(text1) if w.endswith('ableness'))
# Out:
# [u'comfortableness',
#  u'honourableness',
#  u'immutableness',
#  u'indispensableness',
#  u'indomitableness',
#  u'intolerableness',
#  u'palpableness',
#  u'reasonableness',
#  u'uncomfortableness']

# %%
sorted(term for term in set(text4) if 'gnt' in term)
# 단어 안에 gnt가 들어간 단어를 뽑아냄.
# Out:
# [u'Sovereignty', u'sovereignties', u'sovereignty']

# %%
sorted(item for item in set(text6) if item.istitle())
# Out:
# [u'A',
#  u'Aaaaaaaaah',
#  u'Aaaaaaaah',
#  u'Aaaaaah',
#  u'Aaaah',
#  u'Aaaaugh',
#  u'Aaagh',
#  u'Aaah',
#  u'Aaauggh',
#  u'Aaaugh',
#  u'Aaauugh',
#  u'Aagh',
#  u'Aah',
#  u'Aauuggghhh',
#  u'Aauuugh',
#  u'Aauuuuugh',
#  u'Aauuuves',
#  u'Action',
#  u'Actually',
#  u'African',
#  u'Ages',
#  u'Aggh',
#  u'Agh',
#  u'Ah',
#  u'Ahh',
#  u'Alice',
#  u'All',
#  u'Allo',
#  u'Almighty',
#  u'Alright',
#  u'Am',
#  u'Amen',
#  u'An',
#  u'Anarcho',
#  u'And',
#  u'Angnor',
#  u'Anthrax',
#  u'Antioch',
#  u'Anybody',
#  u'Anyway',
#  u'Apples',
#  u'Aramaic',
#  u'Are',
#  u'Arimathea',
#  u'Armaments',
#  u'Arthur',
#  u'As',
#  u'Ask',
#  u'Assyria',
#  u'At',
#  u'Attila',
#  u'Augh',
#  u'Autumn',
#  u'Auuuuuuuugh',
#  u'Away',
#  u'Ay',
#  u'Ayy',
#  u'B',
#  u'Back',
#  u'Bad',
#  u'Badon',
#  u'Battle',
#  u'Be',
#  u'Beast',
#  u'Bedevere',
#  u'Bedwere',
#  u'Behold',
#  u'Between',
#  u'Beyond',
#  u'Black',
#  u'Bloody',
#  u'Blue',
#  u'Bon',
#  u'Bones',
# ...

# %%
sorted(item for item in set(text6))
# Out:
# [u'!',
#  u'!)',
#  u'!,',
#  u'!]',
#  u'#',
#  u"'",
#  u"'!",
#  u"',",
#  u"'.",
#  u"'...",
#  u"'?",
#  u'(',
#  u',',
#  u",'",
#  u',--',
#  u'-',
#  u'--',
#  u'--...',
#  u'.',
#  u".'",
#  u'.)',
#  u'..',
#  u'...',
#  u'...?',
#  u'...]',
#  u'1',
#  u'10',
#  u'11',
#  u'12',
#  u'13',
#  u'14',
#  u'15',
#  u'16',
#  u'17',
#  u'18',
#  u'19',
#  u'2',
#  u'20',
#  u'21',
#  u'22',
#  u'23',
#  u'24',
#  u'3',
#  u'4',
#  u'5',
#  u'6',
#  u'7',
#  u'8',
#  u'9',
#  u':',
#  u';',
#  u'?',
#  u'?!',
#  u'A',
#  u'ALL',
#  u'AMAZING',
#  u'ANIMATOR',
#  u'ARMY',
#  u'ARTHUR',
#  u'Aaaaaaaaah',
#  u'Aaaaaaaah',
#  u'Aaaaaah',
#  u'Aaaah',
#  u'Aaaaugh',
#  u'Aaagh',
#  u'Aaah',
#  u'Aaauggh',
#  u'Aaaugh',
#  u'Aaauugh',
#  u'Aagh',
#  u'Aah',
#  u'Aauuggghhh',
#  u'Aauuugh',
#  u'Aauuuuugh',
#  u'Aauuuves',
#  u'Action',
#  u'Actually',
#  u'African',
#  u'Ages',
#  u'Aggh',
#  u'Agh',
#  u'Ah',
#  u'Ahh',
#  u'Alice',
#  u'All',
#  u'Allo',
#  u'Almighty',
# ...

# %%
sorted(item for item in set(sent7) if item.isdigit())
# Out:
# ['29', '61']

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
[w.upper() for w in text1]
# Out:
# [u'[',
#  u'MOBY',
#  u'DICK',
#  u'BY',
#  u'HERMAN',
#  u'MELVILLE',
#  u'1851',
#  u']',
#  u'ETYMOLOGY',
#  u'.',
#  u'(',
#  u'SUPPLIED',
#  u'BY',
#  u'A',
#  u'LATE',
#  u'CONSUMPTIVE',
#  u'USHER',
#  u'TO',
#  u'A',
#  u'GRAMMAR',
#  u'SCHOOL',
#  u')',
#  u'THE',
#  u'PALE',
#  u'USHER',
#  u'--',
#  u'THREADBARE',
#  u'IN',
#  u'COAT',
#  u',',
#  u'HEART',
#  u',',
#  u'BODY',
#  u',',
#  u'AND',
#  u'BRAIN',
#  u';',
#  u'I',
#  u'SEE',
#  u'HIM',
#  u'NOW',
#  u'.',
#  u'HE',
#  u'WAS',
#  u'EVER',
#  u'DUSTING',
#  u'HIS',
#  u'OLD',
#  u'LEXICONS',
#  u'AND',
#  u'GRAMMARS',
#  u',',
#  u'WITH',
#  u'A',
#  u'QUEER',
#  u'HANDKERCHIEF',
#  u',',
#  u'MOCKINGLY',
#  u'EMBELLISHED',
#  u'WITH',
#  u'ALL',
#  u'THE',
#  u'GAY',
#  u'FLAGS',
#  u'OF',
#  u'ALL',
#  u'THE',
#  u'KNOWN',
#  u'NATIONS',
#  u'OF',
#  u'THE',
#  u'WORLD',
#  u'.',
#  u'HE',
#  u'LOVED',
#  u'TO',
#  u'DUST',
#  u'HIS',
#  u'OLD',
#  u'GRAMMARS',
#  u';',
#  u'IT',
#  u'SOMEHOW',
#  u'MILDLY',
# ...

# %%
#Nested Code Bolocks
word = 'cat'
if len(word) < 5:
    print("길이가 5보다 짧다")
# Out:
# 길이가 5보다 짧다

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
for xyzzy in sent1:
    if xyzzy.endswith('l'):
        print(xyzzy)
# l 이 마지막에 들어간 것만 뽑는다
# Out:
# Call
# Ishmael

# %%
sent1.append('Nathan')
for xyzzy in sent1:
    if xyzzy.endswith('l'):
        print(xyzzy)
# Out:
# Call
# Ishmael

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Nathan']

# %%
for token in sent1:
    if token.islower(): # 소문자로 바꿈
        print(token, 'is a lowercase word')
    elif token.istitle():
        print(token, 'is a titlecase word')
    else:
        print(token, 'is punctuation')
# 범위가 끝나면 다시반복하네?
# Out:
# ('Call', 'is a titlecase word')
# ('me', 'is a lowercase word')
# ('Ishmael', 'is a titlecase word')
# ('.', 'is punctuation')
# ('Nathan', 'is a titlecase word')
